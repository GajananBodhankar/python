# %%
from IPython.display import clear_output
def Input():
    x=input("Enter a number:")
    while(x.isdigit()==False):
        x=input("Enter a number:")
        clear_output()
    temp=int(x)

# %%
# Input()
x=[]
x.insert(4,10)
print(x)
# Out:
# [10]

# %%
def check():
    value="wrong"
    choice="i"
    while value not in range(1,10):
        value=int(input("Enter a value between 1-9:"))
    while choice not in ['X','O']:
        choice=input("Enter a choice X or O")
    print(value,choice)

# %%
print("hello")

# %%
def check():
    player1=input("Enter a choice X or O :").upper()
    player2=""
    while player1 not in ['X','O']:
        player1=input("Enter a choice X or O for player1 :")
    if player1=='X':
        player2='O'
    else:
        player2='X'
    print("player2's choice is {}".format(player2))
    value1=0
    value2=0
    choice="i"
    arr=[' ',' ',' ',' ',' ',' ',' ',' ',' ']
    game=True
    boolOne=False
    boolTwo=False
    while game == True:
        while boolOne==False:
            while value1 not in range(1,10):
                print(arr[0]+'|'+arr[1]+'|'+arr[2])
                print(arr[3]+'|'+arr[4]+'|'+arr[5])
                print(arr[6]+'|'+arr[7]+'|'+arr[8])
                if arr[value1-1]==' ' or value1==0:
                    value1=int(input("Enter player1 value between 1-9:"))
                    if arr[value1-1]==' ' or arr[value1-1]==player1:
                        arr[value1-1]=player1
                        boolOne=True
                        value2=0
                        print(arr[0]+'|'+arr[1]+'|'+arr[2])
                        print(arr[3]+'|'+arr[4]+'|'+arr[5])
                        print(arr[6]+'|'+arr[7]+'|'+arr[8])
                    elif arr[value1-1]==player2:
                        value1=int(input("Sorry, above entered value is already taken,Enter player1 value between 1-9:"))
                        if arr[value1-1]==' ':
                            arr[value1-1]=player1
                            boolOne=True
                            value2=0
                            print(arr[0]+'|'+arr[1]+'|'+arr[2])
                            print(arr[3]+'|'+arr[4]+'|'+arr[5])
                            print(arr[6]+'|'+arr[7]+'|'+arr[8])
                        else:
                            value1=0
                elif arr[value1-1]==player1:
                    value1=int(input("Enter player1 value between 1-9:"))
                    if arr[value1-1]==player2 or arr[value1-1]==player1:
                        value1=int(input("Sorry, above entered value is already taken,Enter player1 value between 1-9:"))
                        if arr[value1-1]==' ':
                            arr[value1-1]=player1
                            boolOne=True
                            value2=0
                            print(arr[0]+'|'+arr[1]+'|'+arr[2])
                            print(arr[3]+'|'+arr[4]+'|'+arr[5])
                            print(arr[6]+'|'+arr[7]+'|'+arr[8])
                        else:
                            value1=0
                    else:
                        arr[value1-1]=player1
                        print(arr)
                        boolOne=True
                        value2=0
                        print(arr[0]+'|'+arr[1]+'|'+arr[2])
                        print(arr[3]+'|'+arr[4]+'|'+arr[5])
                        print(arr[6]+'|'+arr[7]+'|'+arr[8])
                if(arr[0]==arr[1]==arr[2]==player1):
                    print("Player1 is winner")
                    print(arr[0]+'|'+arr[1]+'|'+arr[2])
                    print(arr[3]+'|'+arr[4]+'|'+arr[5])
                    print(arr[6]+'|'+arr[7]+'|'+arr[8])
                    game=False
                    boolOne=True
                    boolTwo=True
                elif(arr[0]==arr[1]==arr[2]==player2):
                    print("Player2 is winner")
                    print(arr[0]+'|'+arr[1]+'|'+arr[2])
                    print(arr[3]+'|'+arr[4]+'|'+arr[5])
                    print(arr[6]+'|'+arr[7]+'|'+arr[8])
                    game=False
                    boolOne=True
                    boolTwo=True
        while boolTwo==False:
            while value2 not in range(1,10):
                if arr[value2]==' ' or value2==0:
                    value2=int(input("Enter player2 value between 1-9:"))
                    if arr[value2-1]==' ':
                        arr[value2-1]=player2
                        boolTwo=True
                        value1=0
                    else:
                        value2=0
                elif arr[value2-1]==player2:
                    value2=int(input("Enter player2 value between 1-9:"))
                    if arr[value2-1]==player2 or arr[value2-1]==player1:
                        value2=int(input("Sorry, above entered value is already taken,Enter player1 value between 1-9:"))
                        if arr[value2]==' ':
                            arr[value2-1]=player2
                            boolOne=True
                            value1=0
                        else:
                            value2=0
                    else:
                        arr[value2-1]=player2
                        print(arr)
                        boolTwo=True
                        value1=0
        if(arr[0]==arr[1]==arr[2]==player1) and game==True:
            print("Player1 is winner")
            print(arr[0]+'|'+arr[1]+'|'+arr[2])
            print(arr[3]+'|'+arr[4]+'|'+arr[5])
            print(arr[6]+'|'+arr[7]+'|'+arr[8])
            game=False
        elif(arr[0]==arr[1]==arr[2]==player2) and game==True:
            print("Player2 is winner")
            print(arr[0]+'|'+arr[1]+'|'+arr[2])
            print(arr[3]+'|'+arr[4]+'|'+arr[5])
            print(arr[6]+'|'+arr[7]+'|'+arr[8])
            game=False
        else:
            boolOne=False
            boolTwo=False
            value1=0
            value2=0
check()
# Out:
# Enter a choice X or O :X
# Enter player1 value between 1-9:5
# [0, 0, 0, 0, 'X', 0, 0, 0, 0]
